# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (1.15.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (3.10.3)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (6.0.2)
# Collecting jinja2>=2.11.1 (from pandas-profiling)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (2.2.5)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (2.32.3)
# Collecting tqdm>=4.48.2 (from pandas-profiling)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting attrs>=19.3.0 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=2.4 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Collecting PyWavelets (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading pywavelets-1.8.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/4.7 MB 2.0 MB/s eta 0:00:03
#    -------- ------------------------------- 1.0/4.7 MB 2.1 MB/s eta 0:00:02
#    --------------- ------------------------ 1.8/4.7 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------ --------------- 2.9/4.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 2.6 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading phik-0.12.4-cp311-cp311-win_amd64.whl (667 kB)
#    ---------------------------------------- 0.0/667.1 kB ? eta -:--:--
#    ---------------------------------------- 667.1/667.1 kB 3.7 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.3 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading pywavelets-1.8.0-cp311-cp311-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.2 MB 5.6 MB/s eta 0:00:01
#    ------------ --------------------------- 1.3/4.2 MB 3.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.8/4.2 MB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.6/4.2 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 3.4/4.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27140 sha256=d41479dc36cf4315f0668993a13548fe399d94697aec998b434aabd15f71a1f0
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, tqdm, tangled-up-in-unicode, PyWavelets, networkx, multimethod, markupsafe, joblib, attrs, jinja2, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.0
#     Uninstalling joblib-1.5.0:
#       Successfully uninstalled joblib-1.5.0
# Successfully installed PyWavelets-1.8.0 attrs-25.3.0 htmlmin-0.1.12 imagehash-4.3.2 jinja2-3.1.6 joblib-1.1.1 markupsafe-2.1.5 missingno-0.5.2 multimethod-2.0 networkx-3.5 pandas-profiling-3.2.0 phik-0.12.4 tangled-up-in-unicode-0.2.0 tqdm-4.67.1 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.6.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.

# %%
# from pandas_profiling import ProfileReport
# prof = ProfileReport(df)
# prof.to_file(output_file='output.html')

# %%
from ydata_profiling import ProfileReport
import pandas as pd

# Example DataFrame
df = pd.read_csv("your_file.csv")  # Replace with your actual file

# Generate the profile
profile = ProfileReport(df)

# Export to HTML
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 import pandas as pd
#       4 # Example DataFrame
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (1.15.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (2.2.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling)
#   Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic>=2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (2.11.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling)
#   Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<=0.61,>=0.56.0 (from ydata-profiling)
#   Downloading numba-0.61.0-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: PyWavelets in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<=0.61,>=0.56.0->ydata-profiling)
#   Downloading llvmlite-0.44.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=2->ydata-profiling) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=2->ydata-profiling) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from pydantic>=2->ydata-profiling) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.1.31)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Collecting typing-extensions>=4.12.2 (from pydantic>=2->ydata-profiling)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\amar\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading matplotlib-3.10.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 985.5 kB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.0 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.0 MB 1.2 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.0 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.0 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.0 MB 2.0 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/8.0 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 2.8 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.0-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.8 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 5.5 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.9 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.9 MB 5.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.9 MB 5.9 MB/s eta 0:00:02
#    ------------- -------------------------- 4.5/12.9 MB 5.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.9 MB 5.3 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.9 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.9 MB 5.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.9 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 5.3 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.9 MB 7.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 6.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 5.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 6.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 6.3 MB/s eta 0:00:00
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl (299 kB)
# Downloading llvmlite-0.44.0-cp311-cp311-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/30.3 MB 7.4 MB/s eta 0:00:04
#    --- ------------------------------------ 2.4/30.3 MB 6.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.4/30.3 MB 5.4 MB/s eta 0:00:05
#    ------ --------------------------------- 4.7/30.3 MB 5.9 MB/s eta 0:00:05
#    -------- ------------------------------- 6.3/30.3 MB 6.3 MB/s eta 0:00:04
#    --------- ------------------------------ 7.1/30.3 MB 5.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 8.7/30.3 MB 6.0 MB/s eta 0:00:04
#    ------------- -------------------------- 10.2/30.3 MB 6.2 MB/s eta 0:00:04
#    -------------- ------------------------- 11.3/30.3 MB 6.3 MB/s eta 0:00:04
#    -------------- ------------------------- 11.3/30.3 MB 6.3 MB/s eta 0:00:04
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\http\client.py", line 473, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\ssl.py", line 1314, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\ssl.py", line 1166, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ssl.SSLError: [SSL] record layer failure (_ssl.c:2580)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\cli\base_command.py", line 106, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\cli\base_command.py", line 97, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\commands\install.py", line 386, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 179, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\operations\prepare.py", line 554, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\operations\prepare.py", line 469, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\network\download.py", line 184, in __call__
#     for chunk in chunks:
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\cli\progress_bars.py", line 55, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\pip\_vendor\urllib3\response.py", line 449, in _error_catcher
#     raise SSLError(e)
# pip._vendor.urllib3.exceptions.SSLError: [SSL] record layer failure (_ssl.c:2580)
